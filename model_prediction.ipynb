# %%
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
import numpy as np
import os

# %%
model = tf.keras.models.load_model("Trained_Model.h5")

# %%
img_path = './test/DRUSEN/DRUSEN-1112835-7.jpeg'
img = tf.keras.utils.load_img(img_path, target_size=(224, 224))
x = tf.keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x
# Out:
# array([[[[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         ...,
#
#         [[  8.,   8.,   8.],
#          [  9.,   9.,   9.],
#          [  8.,   8.,   8.],
#          ...,
#          [  6.,   6.,   6.],
#          [ 26.,  26.,  26.],
#          [  6.,   6.,   6.]],
#
#         [[ 10.,  10.,  10.],
#          [ 12.,  12.,  12.],
#          [ 17.,  17.,  17.],
#          ...,
#          [  8.,   8.,   8.],
#          [  4.,   4.,   4.],
#          [  8.,   8.,   8.]],
#
#         [[ 13.,  13.,  13.],
#          [  3.,   3.,   3.],
#          [ 19.,  19.,  19.],
#          ...,
#          [ 16.,  16.,  16.],
#          [  7.,   7.,   7.],
#          [  6.,   6.,   6.]]]], dtype=float32)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
preds
# Out:
# array([[0.03973182, 0.00854587, 0.927462  , 0.02426029]], dtype=float32)

# %%
class_name = os.listdir("./test")
class_name
# Out:
# ['CNV', 'DME', 'DRUSEN', 'NORMAL']

# %%
result_index = np.argmax(preds)
class_name[result_index]
# Out:
# 'DRUSEN'
